# %%
import os
from dotenv import load_dotenv
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_core.models import UserMessage
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.agents import AssistantAgent
from autogen_core import CancellationToken


load_dotenv(override=True)

model_client = OpenAIChatCompletionClient(
    model="stepfun-ai/step-3.7-flash",
    api_key=os.getenv("STEPFUN_API_KEY"),
    base_url="https://integrate.api.nvidia.com/v1"
)

message = TextMessage(content="I'd like to go to london", source="user")

agent = AssistantAgent(name="airline agent", model_client=model_client, system_prompt="You are an airline booking assistant. Help the user book a flight to their desired destination.", model_client_stream=True)

response = await agent.on_messages([message], cancellation_token=CancellationToken())

print(response.chat_message.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       8
#       9
#      10 load_dotenv(override=True)
#      11
# ---> 12 model_client = OpenAIChatCompletionClient(
#      13     model="step-3.7-flash",
#      14     api_key=os.getenv("STEPFUN_API_KEY"),
#      15     base_url="https://integrate.api.nvidia.com/v1"
#
# File d:\AI Agents Course\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:1487, in OpenAIChatCompletionClient.__init__(self, **kwargs)
#    1484 client = _openai_client_from_config(copied_args)
#    1485 create_args = _create_args_from_config(copied_args)
# -> 1487 super().__init__(
#    1488     client=client,
#    1489     create_args=create_args,
#    1490     model_capabilities=model_capabilities,
#    1491     model_info=model_info,
#    1492     add_name_prefixes=add_name_prefixes,
#    1493     include_name_in_message=include_name_in_message,
#    1494 )
#
# File d:\AI Agents Course\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:448, in BaseOpenAIChatCompletionClient.__init__(self, client, create_args, model_capabilities, model_info, add_name_prefixes, include_name_in_message)
#     446 if model_capabilities is None and model_info is None:
#     447     try:
# --> 448         self._model_info = _model_info.get_info(create_args["model"])
#     449     except KeyError as err:
#     450         raise ValueError("model_info is required when model name is not a valid OpenAI model") from err
#
# File d:\AI Agents Course\.venv\Lib\site-packages\autogen_ext\models\openai\_model_info.py:521, in get_info(model)
#     510 model_info: ModelInfo = _MODEL_INFO.get(
#     511     resolved_model,
#     512     {
#    (...)    518     },
#     519 )
#     520 if model_info.get("family") == "FAILED":
# --> 521     raise ValueError("model_info is required when model name is not a valid OpenAI model")
#     522 if model_info.get("family") == ModelFamily.UNKNOWN:
#     523     trace_logger.warning(f"Model info not found for model: {model}")
#
# ValueError: model_info is required when model name is not a valid OpenAI model
