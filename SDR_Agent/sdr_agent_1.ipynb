# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="SDR agent", instructions="you are a joke teller", model="gpt-4o-mini")

# %%
with trace("telling a joke"):
    result = await Runner.run(agent, "Tell me joke about autonomous AI agents.")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# It just couldn't find the right "algorithm" for love!

# %% [markdown]
# https://platform.openai.com/traces
